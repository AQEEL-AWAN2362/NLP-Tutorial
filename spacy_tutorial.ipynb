# %%
# object oriented library
import spacy

# %%
nlp=spacy.blank("en")
doc=nlp("Dr. Strange loves pav bhaji of mumbai as it costs only 2$ per plate")
for token in doc:
  print(token)
# Out:
# Dr.
# Strange
# loves
# pav
# bhaji
# of
# mumbai
# as
# it
# costs
# only
# 2
# $
# per
# plate

# %%
type(nlp), type(doc), type(token)
# Out:
# (spacy.lang.en.English, spacy.tokens.doc.Doc, spacy.tokens.token.Token)

# %%
doc[0]     ,    doc[2:7]
# Out:
# (Dr., loves pav bhaji of mumbai)

# %%
doc1=nlp("tony gives 2 $ to peter")
token0=doc1[0]
token1=doc1[1]
token2=doc1[2]
token0, token1, token2
# Out:
# (tony, gives, 2)

# %%
token0.text, token1.is_title, token2.like_num
# Out:
# ('tony', False, True)

# %%
dir(token0)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
# ...

# %%
# open file that is on desktop
with open("/content/Document123.txt") as f:
  text=f.readlines()
text
# Out:
# ["{\\rtf1 \\ansi \\ansicpg1252 \\deff0 \\stshfdbch2 \\stshfloch0 \\stshfhich0 \\deflang2057 \\deflangfe2057 {\\fonttbl {\\f0 \\froman \\fcharset0 \\fprq2 {\\*\\panose 02020603050405020304}Times New Roman{\\*\\falt Times New Roman};}{\\f2 \\fnil \\fcharset134 \\fprq0 {\\*\\panose 02010600030101010101}SimSun{\\*\\falt SimSun};}{\\f3 \\fnil \\fcharset2 \\fprq0 {\\*\\panose 05000000000000000000}Wingdings{\\*\\falt Wingdings};}{\\f4 \\fswiss \\fcharset0 \\fprq0 {\\*\\panose 020f0502020204030204}Calibri{\\*\\falt Calibri};}}{\\colortbl;\\red0\\green0\\blue0;\\red128\\green0\\blue0;\\red255\\green0\\blue0;\\red0\\green128\\blue0;\\red128\\green128\\blue0;\\red0\\green255\\blue0;\\red255\\green255\\blue0;\\red0\\green0\\blue128;\\red128\\green0\\blue128;\\red0\\green128\\blue128;\\red128\\green128\\blue128;\\red192\\green192\\blue192;\\red0\\green0\\blue255;\\red255\\green0\\blue255;\\red0\\green255\\blue255;\\red255\\green255\\blue255;}{\\stylesheet {\\qj \\li0 \\ri0 \\widctlpar \\aspalpha 
# ...

# %%
text=" ".join(text)
text
# Out:
# "{\\rtf1 \\ansi \\ansicpg1252 \\deff0 \\stshfdbch2 \\stshfloch0 \\stshfhich0 \\deflang2057 \\deflangfe2057 {\\fonttbl {\\f0 \\froman \\fcharset0 \\fprq2 {\\*\\panose 02020603050405020304}Times New Roman{\\*\\falt Times New Roman};}{\\f2 \\fnil \\fcharset134 \\fprq0 {\\*\\panose 02010600030101010101}SimSun{\\*\\falt SimSun};}{\\f3 \\fnil \\fcharset2 \\fprq0 {\\*\\panose 05000000000000000000}Wingdings{\\*\\falt Wingdings};}{\\f4 \\fswiss \\fcharset0 \\fprq0 {\\*\\panose 020f0502020204030204}Calibri{\\*\\falt Calibri};}}{\\colortbl;\\red0\\green0\\blue0;\\red128\\green0\\blue0;\\red255\\green0\\blue0;\\red0\\green128\\blue0;\\red128\\green128\\blue0;\\red0\\green255\\blue0;\\red255\\green255\\blue0;\\red0\\green0\\blue128;\\red128\\green0\\blue128;\\red0\\green128\\blue128;\\red128\\green128\\blue128;\\red192\\green192\\blue192;\\red0\\green0\\blue255;\\red255\\green0\\blue255;\\red0\\green255\\blue255;\\red255\\green255\\blue255;}{\\stylesheet {\\qj \\li0 \\ri0 \\widctlpar \\aspalpha \
# ...

# %%
doc2=nlp(text)
emails=[]
for token in doc2:
  if token.like_email:
    emails.append(token.text)
emails
# Out:
# ['khan@email.com}{\\fs22',
#  'carmen.r@email.com}{\\fs22',
#  'david_lee87@email.com}{\\fs22',
#  'f.noor@email.com}{\\fs22',
#  'geo.smith77@email.com}{\\fs22',
#  'hiro.tanaka@email.com}{\\fs22']
